# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading the csv file on the pandas dataframe
df = pd.read_csv('C:/Users/25401017/python project/six-point-board-thickness.csv')
#extracting information about the file
df.info()
#displaying the first five rows
df.head(500)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date.Time  5000 non-null   object
#  1   Pos1       5000 non-null   int64
#  2   Pos2       5000 non-null   int64
#  3   Pos3       5000 non-null   int64
#  4   Pos4       5000 non-null   int64
#  5   Pos5       5000 non-null   int64
#  6   Pos6       5000 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 273.6+ KB
#                Date.Time  Pos1  Pos2  Pos3  Pos4  Pos5  Pos6
# 0    2010-02-18 03:04:46  1761  1739  1758  1677  1684  1692
# 1    2010-02-18 03:37:01  1801  1688  1753  1741  1692  1675
# 2    2010-02-18 03:37:01  1697  1682  1663  1671  1685  1651
# 3    2010-02-18 03:37:01  1679  1712  1672  1703  1683  1674
# 4    2010-02-18 03:37:10  1699  1688  1699  1678  1688  1705
# ..                   ...   ...   ...   ...   ...   ...   ...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos1'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos2'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos3'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos4'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos5'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Pos6'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# I decided to use the time series to show the the thickness of the wood at several positions. From the graph I observed that pos1 has the smallest thickness and pos 2 has the highest thickness. Also from the dataframe, the thickness tends to flunctuate between the various positions.Rows 495, 497, 498, and 499 are not consistent with their thickness.
